# %% [markdown]
# # Digital Assignment 1 Machine Learning - Data Preprocessing And Exploratory Data Analysis
# ## By Group 02
# - Adithya Nair - AID23002,
# - Avighna Reddy Katipally - AID23005
# - P Ananthapadmanabhan Nair - AID23036

# %% [markdown]
# **Dataset used -** The dataset used in the assignment is a csv file of the global economy indicators of all the major political regions of our world tracked at various points in time.
#
# [Dataset can be found here](https://www.kaggle.com/datasets/prasad22/global-economy-indicators)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('GlobalEconomyIndicators.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10512 entries, 0 to 10511
# Data columns (total 26 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0    CountryID                                                                                  10512 non-null  int64
#  1    Country                                                                                    10512 non-null  object
#  2    Year                                                                                       10512 non-null  int64
#  3    AMA exchange rate                                                                          10512 non-null  float64
#  4    IMF based exchange rate                                                                    10512 non-null  float64
#  5    Population                                                                                 10512 non-null  int64
#  6    Currency                                                                                   10512 non-null  object
#  7    Per capita GNI                                                                             10512 non-null  int64
#  8    Agriculture, hunting, forestry, fishing (ISIC A-B)                                         10391 non-null  float64
#  9    Changes in inventories                                                                     8671 non-null   float64
#  10   Construction (ISIC F)                                                                      10512 non-null  float64
#  11   Exports of goods and services                                                              10491 non-null  float64
#  12   Final consumption expenditure                                                              10512 non-null  float64
#  13   General government final consumption expenditure                                           10460 non-null  float64
#  14   Gross capital formation                                                                    10460 non-null  float64
#  15   Gross fixed capital formation (including Acquisitions less disposals of valuables)         10460 non-null  float64
#  16   Household consumption expenditure (including Non-profit institutions serving households)   10460 non-null  float64
#  17   Imports of goods and services                                                              10470 non-null  float64
#  18   Manufacturing (ISIC D)                                                                     10469 non-null  float64
#  19   Mining, Manufacturing, Utilities (ISIC C-E)                                                10512 non-null  float64
#  20   Other Activities (ISIC J-P)                                                                10512 non-null  float64
#  21   Total Value Added                                                                          10512 non-null  float64
#  22   Transport, storage and communication (ISIC I)                                              10463 non-null  float64
#  23   Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                 10463 non-null  float64
#  24   Gross National Income(GNI) in USD                                                          10512 non-null  float64
#  25   Gross Domestic Product (GDP)                                                               10512 non-null  float64
# dtypes: float64(20), int64(4), object(2)
# memory usage: 2.1+ MB
# None

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Dealing with Missing Values

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
# CountryID                                                                                       0
# Country                                                                                         0
# Year                                                                                            0
# AMA exchange rate                                                                               0
# IMF based exchange rate                                                                         0
# Population                                                                                      0
# Currency                                                                                        0
# Per capita GNI                                                                                  0
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                            121
# Changes in inventories                                                                       1841
# Construction (ISIC F)                                                                           0
# Exports of goods and services                                                                  21
# Final consumption expenditure                                                                   0
# General government final consumption expenditure                                               52
# Gross capital formation                                                                        52
# Gross fixed capital formation (including Acquisitions less disposals of valuables)             52
# Household consumption expenditure (including Non-profit institutions serving households)       52
# Imports of goods and services                                                                  42
# Manufacturing (ISIC D)                                                                         43
# Mining, Manufacturing, Utilities (ISIC C-E)                                                     0
# Other Activities (ISIC J-P)                                                                     0
# Total Value Added                                                                               0
# Transport, storage and communication (ISIC I)                                                  49
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                     49
# Gross National Income(GNI) in USD                                                               0
# Gross Domestic Product (GDP)                                                                    0
# dtype: int64

# %% [markdown]
# As seen here, there are missing values located in several columns, we proceed by opting to replace the missing values found in 'Changes In Inventories' with the mean(since it is a continuous feature).
#
# Now we delete the rows with missing values, found in the other columns.

# %%
df[' Changes in inventories '] = df[' Changes in inventories '].fillna(df[' Changes in inventories '].mean())
print("\n Missing values in 'Changes in inventories' column after filling with mean:" , df[' Changes in inventories '].isnull().sum())

df.dropna()
print("\n Missing values in each column after handling them:")
print(df.isnull().sum())
# Out:
#  Missing values in 'Changes in inventories' column after filling with mean: 0
#
#  Missing values in each column after handling them:
# CountryID                                                                                      0
# Country                                                                                        0
# Year                                                                                           0
# AMA exchange rate                                                                              0
# IMF based exchange rate                                                                        0
# Population                                                                                     0
# Currency                                                                                       0
# Per capita GNI                                                                                 0
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           121
# Changes in inventories                                                                         0
# Construction (ISIC F)                                                                          0
# Exports of goods and services                                                                 21
# Final consumption expenditure                                                                  0
# General government final consumption expenditure                                              52
# Gross capital formation                                                                       52
# Gross fixed capital formation (including Acquisitions less disposals of valuables)            52
# Household consumption expenditure (including Non-profit institutions serving households)      52
# Imports of goods and services                                                                 42
# Manufacturing (ISIC D)                                                                        43
# Mining, Manufacturing, Utilities (ISIC C-E)                                                    0
# Other Activities (ISIC J-P)                                                                    0
# Total Value Added                                                                              0
# Transport, storage and communication (ISIC I)                                                 49
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                    49
# Gross National Income(GNI) in USD                                                              0
# Gross Domestic Product (GDP)                                                                   0
# dtype: int64

# %% [markdown]
# ## Duplicates

# %%
duplicate_rows = df[df.duplicated()]
print("Number of Duplicate Rows = " , duplicate_rows.shape)

df = df.drop_duplicates()
print("Size of the Dataset after removing the duplicates = " , df.shape)
# Out:
# Number of Duplicate Rows =  (0, 26)
# Size of the Dataset after removing the duplicates =  (10512, 26)

# %% [markdown]
# There are no duplicates in this dataset, no further action needs to be taken.

# %% [markdown]
# # Normalisation

# %%
exclude_columns = [' CountryID ',' Country ',' Currency '] #caltegorical columns
column = df.drop(columns=exclude_columns).columns.tolist() #numerical columns

range_of_columns = df[column].max() - df[column].min()
print(range_of_columns)
# Out:
# Year                                                                                         5.100000e+01
# AMA exchange rate                                                                            1.116366e+05
# IMF based exchange rate                                                                      4.200000e+04
# Population                                                                                   1.425889e+09
# Per capita GNI                                                                               2.342830e+05
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           1.350000e+12
# Changes in inventories                                                                       3.620000e+11
# Construction (ISIC F)                                                                        1.240000e+12
# Exports of goods and services                                                                3.531670e+12
# Final consumption expenditure                                                                1.930000e+13
# General government final consumption expenditure                                             3.349999e+12
# Gross capital formation                                                                      7.643970e+12
# Gross fixed capital formation (including Acquisitions less disposals of valuables)           7.430000e+12
# Household consumption expenditure (including Non-profit institutions serving households)     1.590000e+13
# Imports of goods and services                                                                3.399998e+12
# Manufacturing (ISIC D)                                                                       4.870000e+12
# Mining, Manufacturing, Utilities (ISIC C-E)                                                  5.780003e+12
# Other Activities (ISIC J-P)                                                                  1.290000e+13
# Total Value Added                                                                            2.330000e+13
# Transport, storage and communication (ISIC I)                                                2.490006e+12
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   3.520000e+12
# Gross National Income(GNI) in USD                                                            2.360000e+13
# Gross Domestic Product (GDP)                                                                 2.330000e+13
# dtype: float64

# %% [markdown]
# The data found in this dataset firmly exists in ranges which demand normalization. We proceed by normalizing the values except for the 3 categorical features as noted above.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
columns_to_normalize = column[1:]
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

range_of_columns = df[column].max() - df[column].min()
print(range_of_columns)
# Out:
# Year                                                                                         51.000000
# AMA exchange rate                                                                            48.727940
# IMF based exchange rate                                                                      21.629805
# Population                                                                                   12.494190
# Per capita GNI                                                                               13.725326
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           33.464260
# Changes in inventories                                                                       44.624753
# Construction (ISIC F)                                                                        24.872828
# Exports of goods and services                                                                20.195126
# Final consumption expenditure                                                                25.552841
# General government final consumption expenditure                                             21.310303
# Gross capital formation                                                                      28.600322
# Gross fixed capital formation (including Acquisitions less disposals of valuables)           28.361970
# Household consumption expenditure (including Non-profit institutions serving households)     26.332502
# Imports of goods and services                                                                18.844234
# Manufacturing (ISIC D)                                                                       28.251092
# Mining, Manufacturing, Utilities (ISIC C-E)                                                  27.361274
# Other Activities (ISIC J-P)                                                                  26.651033
# Total Value Added                                                                            23.908278
# Transport, storage and communication (ISIC I)                                                27.103823
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   25.293517
# Gross National Income(GNI) in USD                                                            23.738459
# Gross Domestic Product (GDP)                                                                 23.665564
# dtype: float64

# %% [markdown]
# # Handling Categorical Data
# ## Label Encoding
# We have taken the countries and converted them into a categorical value readable by the machine as well as the currency

# %%
from sklearn.preprocessing import LabelEncoder


columns_to_encode = [' CountryID ',' Country ',' Currency ']
label_encoder = LabelEncoder()

for col in columns_to_encode:
    df[col] = label_encoder.fit_transform(df[col])
    print(df[col])
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 10507    219
# 10508    219
# 10509    219
# 10510    219
# 10511    219
# Name:  CountryID , Length: 10512, dtype: int64
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 10507    217
# 10508    217
# 10509    217
# 10510    217
# 10511    217
# Name:  Country , Length: 10512, dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 10507    70
# 10508    70
# 10509    70
# 10510    70
# 10511    70
# Name:  Currency , Length: 10512, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA) and Outliers
# ## Plotting box plots for each numeric column

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns

df[numerical_columns].plot(kind='box', subplots=True, layout=(len(column)+1, 1), figsize=(10, 50), patch_artist=True)
# Out:
# CountryID                                                                                    Axes(0.125,0.853077;0.775x0.0269231)
# Year                                                                                         Axes(0.125,0.820769;0.775x0.0269231)
# AMA exchange rate                                                                            Axes(0.125,0.788462;0.775x0.0269231)
# IMF based exchange rate                                                                      Axes(0.125,0.756154;0.775x0.0269231)
# Population                                                                                   Axes(0.125,0.723846;0.775x0.0269231)
# Per capita GNI                                                                               Axes(0.125,0.691538;0.775x0.0269231)
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           Axes(0.125,0.659231;0.775x0.0269231)
# Changes in inventories                                                                       Axes(0.125,0.626923;0.775x0.0269231)
# Construction (ISIC F)                                                                        Axes(0.125,0.594615;0.775x0.0269231)
# Exports of goods and services                                                                Axes(0.125,0.562308;0.775x0.0269231)
# Final consumption expenditure                                                                    Axes(0.125,0.53;0.775x0.0269231)
# General government final consumption expenditure                                             Axes(0.125,0.497692;0.775x0.0269231)
# Gross capital formation                                                                      Axes(0.125,0.465385;0.775x0.0269231)
# Gross fixed capital formation (including Acquisitions less disposals of valuables)           Axes(0.125,0.433077;0.775x0.0269231)
# Household consumption expenditure (including Non-profit institutions serving households)     Axes(0.125,0.400769;0.775x0.0269231)
# Imports of goods and services                                                                Axes(0.125,0.368462;0.775x0.0269231)
# Manufacturing (ISIC D)                                                                       Axes(0.125,0.336154;0.775x0.0269231)
# Mining, Manufacturing, Utilities (ISIC C-E)                                                  Axes(0.125,0.303846;0.775x0.0269231)
# Other Activities (ISIC J-P)                                                                  Axes(0.125,0.271538;0.775x0.0269231)
# Total Value Added                                                                            Axes(0.125,0.239231;0.775x0.0269231)
# Transport, storage and communication (ISIC I)                                                Axes(0.125,0.206923;0.775x0.0269231)
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   Axes(0.125,0.174615;0.775x0.0269231)
# Gross National Income(GNI) in USD                                                            Axes(0.125,0.142308;0.775x0.0269231)
# Gross Domestic Product (GDP)                                                                     Axes(0.125,0.11;0.775x0.0269231)
# dtype: object

# %% [markdown]
# ## Calculating outliers for each feature

# %%
for col in column:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        # Define lower and upper bounds
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Identify outliers
        outliers_lower = df[col] < lower_bound
        outliers_upper = df[col] > upper_bound

        # Transform outliers by capping them at the bounds
        df.loc[outliers_lower, col] = lower_bound
        df.loc[outliers_upper, col] = upper_bound

        print(f"Column: {col}")
        print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")
        print(f"Number of lower outliers: {outliers_lower.sum()}")
        print(f"Number of upper outliers: {outliers_upper.sum()}\n")
# Out:
# (10512, 26)
# Column:  Year
# Lower Bound: 1946.5, Upper Bound: 2046.5
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  AMA exchange rate
# Lower Bound: -0.18852337282591658, Upper Bound: -0.10062682260943201
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  IMF based exchange rate
# Lower Bound: -0.21196431014688188, Upper Bound: -0.11500748825343876
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Population
# Lower Bound: -0.45665611295000086, Upper Bound: 0.10958877688856455
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Per capita GNI
# Lower Bound: -1.2062050749277657, Upper Bound: 0.7237404241001171
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Agriculture, hunting, forestry, fishing (ISIC A-B)
# Lower Bound: -0.3346939332225747, Upper Bound: 0.05129760193180735
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Changes in inventories
# Lower Bound: -0.5000653766322178, Upper Bound: 0.3000392259793308
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Construction (ISIC F)
# Lower Bound: -0.2823306560629018, Upper Bound: -0.06187912134636113
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Exports of goods and services
# Lower Bound: -0.39366138128022243, Upper Bound: -0.05005492576859061
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Final consumption expenditure
# Lower Bound: -0.25089610819451513, Upper Bound: -0.056924949767906935
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  General government final consumption expenditure
# Lower Bound: -0.26371018319581413, Upper Bound: -0.08025213293163642
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Gross capital formation
# Lower Bound: -0.24115928060895014, Upper Bound: -0.05959249547171715
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Gross fixed capital formation (including Acquisitions less disposals of valuables)
# Lower Bound: -0.23663729643355907, Upper Bound: -0.06281361897939447
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Household consumption expenditure (including Non-profit institutions serving households)
# Lower Bound: -0.24558827180483764, Upper Bound: -0.052482825594958066
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Imports of goods and services
# Lower Bound: -0.3795278323348511, Upper Bound: -0.037361236292915795
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Manufacturing (ISIC D)
# Lower Bound: -0.24223150041016023, Upper Bound: -0.07297059838460566
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Mining, Manufacturing, Utilities (ISIC C-E)
# Lower Bound: -0.28326443305960936, Upper Bound: -0.04983457652609177
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Other Activities (ISIC J-P)
# Lower Bound: -0.197275209286351, Upper Bound: -0.08103773062026974
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Total Value Added
# Lower Bound: -0.24973124753126863, Upper Bound: -0.05749729334562448
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Transport, storage and communication (ISIC I)
# Lower Bound: -0.23192151348237428, Upper Bound: -0.06272857948250993
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Wholesale, retail trade, restaurants and hotels (ISIC G-H)
# Lower Bound: -0.24889096592091428, Upper Bound: -0.062075816822948354
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Gross National Income(GNI) in USD
# Lower Bound: -0.2555766728446649, Upper Bound: -0.05984653626748962
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  Gross Domestic Product (GDP)
# Lower Bound: -0.26089752385561554, Upper Bound: -0.05659464085712457
# Number of lower outliers: 0
# Number of upper outliers: 0

# %% [markdown]
# # Data Visualization
# ## Distribution of numerical columns

# %%
print("\nDistribution of numerical columns:")
for col in column:
    plt.figure(figsize=(10, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# Distribution of numerical columns:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 print("\nDistribution of numerical columns:")
#       2 for col in column:
# ----> 3     plt.figure(figsize=(10, 4))
#       4     sns.histplot(df[col], kde=True, bins=30)
#       5     plt.title(f'Distribution of {col}')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Distribution of categorical columns

# %%
# Distribution of categorical columns

print("\n Distribution of categorical columns:")
for col in exclude_columns:
    
    """ plt.figure(figsize=(30,30))
    sns.countplot(y=df[col], order=df[col].value_counts().index)
    plt.title(f'Distribution of {col}')
    plt.show() """
    
    plt.figure(figsize=(10,10))
    vc = df[col].value_counts()
    y = list(range(0,  len(vc)))
    plt.scatter(vc, y, marker='o', linestyle='-', color='b')
    plt.title(f'Distribution of {col}')
    plt.xlabel('Categories') #from label encoding, we get the categories from 0 to 1
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Correlation Analysis

# %%
corr_matrix = df[column].corr()
plt.figure(figsize=(12,10))  
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1, center=0, fmt='.2f')
plt.title('Correlation Matrix')
plt.show()
