# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('GlobalEconomyIndicators.csv')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10512 entries, 0 to 10511
# Data columns (total 26 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0    CountryID                                                                                  10512 non-null  int64
#  1    Country                                                                                    10512 non-null  object
#  2    Year                                                                                       10512 non-null  int64
#  3    AMA exchange rate                                                                          10512 non-null  float64
#  4    IMF based exchange rate                                                                    10512 non-null  float64
#  5    Population                                                                                 10512 non-null  int64
#  6    Currency                                                                                   10512 non-null  object
#  7    Per capita GNI                                                                             10512 non-null  int64
#  8    Agriculture, hunting, forestry, fishing (ISIC A-B)                                         10391 non-null  float64
#  9    Changes in inventories                                                                     8671 non-null   float64
#  10   Construction (ISIC F)                                                                      10512 non-null  float64
#  11   Exports of goods and services                                                              10491 non-null  float64
#  12   Final consumption expenditure                                                              10512 non-null  float64
#  13   General government final consumption expenditure                                           10460 non-null  float64
#  14   Gross capital formation                                                                    10460 non-null  float64
#  15   Gross fixed capital formation (including Acquisitions less disposals of valuables)         10460 non-null  float64
#  16   Household consumption expenditure (including Non-profit institutions serving households)   10460 non-null  float64
#  17   Imports of goods and services                                                              10470 non-null  float64
#  18   Manufacturing (ISIC D)                                                                     10469 non-null  float64
#  19   Mining, Manufacturing, Utilities (ISIC C-E)                                                10512 non-null  float64
#  20   Other Activities (ISIC J-P)                                                                10512 non-null  float64
#  21   Total Value Added                                                                          10512 non-null  float64
#  22   Transport, storage and communication (ISIC I)                                              10463 non-null  float64
#  23   Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                 10463 non-null  float64
#  24   Gross National Income(GNI) in USD                                                          10512 non-null  float64
#  25   Gross Domestic Product (GDP)                                                               10512 non-null  float64
# dtypes: float64(20), int64(4), object(2)
# memory usage: 2.1+ MB
# None

# %%
# Bining the target class for classification

df['Outcome'] = pd.qcut(df[' Gross Domestic Product (GDP) '], q=3, labels=['Low', 'Medium', 'High'])

frequency = df['Outcome'].value_counts()
print(frequency)

df = df.drop(' Gross Domestic Product (GDP) ', axis = 1)
# Out:
# Outcome
# Low       3504
# Medium    3504
# High      3504
# Name: count, dtype: int64

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Dealing with Missing Values

# %%
print("\nMissing values in each column:")
print(df.isnull().sum())
# Out:
# Missing values in each column:
#  CountryID                                                                                       0
#  Country                                                                                         0
#  Year                                                                                            0
#  AMA exchange rate                                                                               0
#  IMF based exchange rate                                                                         0
#  Population                                                                                      0
#  Currency                                                                                        0
#  Per capita GNI                                                                                  0
#  Agriculture, hunting, forestry, fishing (ISIC A-B)                                            121
#  Changes in inventories                                                                       1841
#  Construction (ISIC F)                                                                           0
#  Exports of goods and services                                                                  21
#  Final consumption expenditure                                                                   0
#  General government final consumption expenditure                                               52
#  Gross capital formation                                                                        52
#  Gross fixed capital formation (including Acquisitions less disposals of valuables)             52
#  Household consumption expenditure (including Non-profit institutions serving households)       52
#  Imports of goods and services                                                                  42
#  Manufacturing (ISIC D)                                                                         43
#  Mining, Manufacturing, Utilities (ISIC C-E)                                                     0
#  Other Activities (ISIC J-P)                                                                     0
#  Total Value Added                                                                               0
#  Transport, storage and communication (ISIC I)                                                  49
#  Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                     49
#  Gross National Income(GNI) in USD                                                               0
# Outcome                                                                                          0
# dtype: int64

# %% [markdown]
# As seen here, there are missing values located in several columns, we proceed by opting to replace the missing values found in 'Changes In Inventories' with the mean(since it is a continuous feature).
#
# Now we delete the rows with missing values, found in the other columns.

# %%
df[' Changes in inventories '] = df[' Changes in inventories '].fillna(df[' Changes in inventories '].mean())
print("\n Missing values in 'Changes in inventories' column after filling with mean:" , df[' Changes in inventories '].isnull().sum())

df = df.dropna()
print("\n Missing values in each column after handling them:")
print(df.isnull().sum())
# Out:
#  Missing values in 'Changes in inventories' column after filling with mean: 0
#
#  Missing values in each column after handling them:
#  CountryID                                                                                    0
#  Country                                                                                      0
#  Year                                                                                         0
#  AMA exchange rate                                                                            0
#  IMF based exchange rate                                                                      0
#  Population                                                                                   0
#  Currency                                                                                     0
#  Per capita GNI                                                                               0
#  Agriculture, hunting, forestry, fishing (ISIC A-B)                                           0
#  Changes in inventories                                                                       0
#  Construction (ISIC F)                                                                        0
#  Exports of goods and services                                                                0
#  Final consumption expenditure                                                                0
#  General government final consumption expenditure                                             0
#  Gross capital formation                                                                      0
#  Gross fixed capital formation (including Acquisitions less disposals of valuables)           0
#  Household consumption expenditure (including Non-profit institutions serving households)     0
#  Imports of goods and services                                                                0
#  Manufacturing (ISIC D)                                                                       0
#  Mining, Manufacturing, Utilities (ISIC C-E)                                                  0
#  Other Activities (ISIC J-P)                                                                  0
#  Total Value Added                                                                            0
#  Transport, storage and communication (ISIC I)                                                0
#  Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   0
#  Gross National Income(GNI) in USD                                                            0
# Outcome                                                                                       0
# dtype: int64

# %% [markdown]
# # Normalisation

# %%
exclude_columns = [' CountryID ',' Country ',' Currency ','Outcome'] #categorical columns
column = df.drop(columns=exclude_columns).columns.tolist() #numerical columns

range_of_columns = df[column].max() - df[column].min()
print(range_of_columns)
# Out:
# Year                                                                                         5.100000e+01
# AMA exchange rate                                                                            1.116366e+05
# IMF based exchange rate                                                                      4.200000e+04
# Population                                                                                   1.425889e+09
# Per capita GNI                                                                               1.982600e+05
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           1.350000e+12
# Changes in inventories                                                                       3.620000e+11
# Construction (ISIC F)                                                                        1.240000e+12
# Exports of goods and services                                                                3.530000e+12
# Final consumption expenditure                                                                1.930000e+13
# General government final consumption expenditure                                             3.349999e+12
# Gross capital formation                                                                      7.643970e+12
# Gross fixed capital formation (including Acquisitions less disposals of valuables)           7.430000e+12
# Household consumption expenditure (including Non-profit institutions serving households)     1.590000e+13
# Imports of goods and services                                                                3.399998e+12
# Manufacturing (ISIC D)                                                                       4.870000e+12
# Mining, Manufacturing, Utilities (ISIC C-E)                                                  5.780003e+12
# Other Activities (ISIC J-P)                                                                  1.290000e+13
# Total Value Added                                                                            2.330000e+13
# Transport, storage and communication (ISIC I)                                                2.490006e+12
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   3.520000e+12
# Gross National Income(GNI) in USD                                                            2.360000e+13
# dtype: float64

# %% [markdown]
# The data found in this dataset firmly exists in ranges which demand normalization. We proceed by normalizing the values except for the 3 categorical features as noted above.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
columns_to_normalize = column[1:]
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

range_of_columns = df[column].max() - df[column].min()
print(range_of_columns)
# Out:
# Year                                                                                         51.000000
# AMA exchange rate                                                                            48.140015
# IMF based exchange rate                                                                      21.370488
# Population                                                                                   14.652585
# Per capita GNI                                                                               13.007812
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                           33.902709
# Changes in inventories                                                                       44.809358
# Construction (ISIC F)                                                                        24.617717
# Exports of goods and services                                                                19.985557
# Final consumption expenditure                                                                25.258448
# General government final consumption expenditure                                             21.127146
# Gross capital formation                                                                      28.369742
# Gross fixed capital formation (including Acquisitions less disposals of valuables)           28.130488
# Household consumption expenditure (including Non-profit institutions serving households)     26.088900
# Imports of goods and services                                                                18.670109
# Manufacturing (ISIC D)                                                                       28.026367
# Mining, Manufacturing, Utilities (ISIC C-E)                                                  27.123028
# Other Activities (ISIC J-P)                                                                  26.331664
# Total Value Added                                                                            23.641034
# Transport, storage and communication (ISIC I)                                                26.842655
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   25.056982
# Gross National Income(GNI) in USD                                                            23.471900
# dtype: float64

# %% [markdown]
# # Handling Categorical Data
# ## Label Encoding
# We have taken the countries and converted them into a categorical value readable by the machine as well as the currency

# %%
from sklearn.preprocessing import LabelEncoder


columns_to_encode = [' CountryID ',' Country ',' Currency ']
label_encoder = LabelEncoder()

for col in columns_to_encode:
    df[col] = label_encoder.fit_transform(df[col])
    print(df[col])
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 10507    213
# 10508    213
# 10509    213
# 10510    213
# 10511    213
# Name:  CountryID , Length: 10254, dtype: int64
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#         ...
# 10507    211
# 10508    211
# 10509    211
# 10510    211
# 10511    211
# Name:  Country , Length: 10254, dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 10507    69
# 10508    69
# 10509    69
# 10510    69
# 10511    69
# Name:  Currency , Length: 10254, dtype: int64

# %% [markdown]
# # Exploratory Data Analysis (EDA) and Outliers
# ## Plotting box plots for each numeric column

# %%
len(column)+3
# Out:
# 25

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns
df[numerical_columns].plot(kind='box', subplots=True, layout=(13, 2), figsize=(10, 50), patch_artist=True)
# Out:
# CountryID                                                                                       Axes(0.125,0.83;0.352273x0.05)
# Country                                                                                      Axes(0.547727,0.83;0.352273x0.05)
# Year                                                                                            Axes(0.125,0.77;0.352273x0.05)
# AMA exchange rate                                                                            Axes(0.547727,0.77;0.352273x0.05)
# IMF based exchange rate                                                                         Axes(0.125,0.71;0.352273x0.05)
# Population                                                                                   Axes(0.547727,0.71;0.352273x0.05)
# Currency                                                                                        Axes(0.125,0.65;0.352273x0.05)
# Per capita GNI                                                                               Axes(0.547727,0.65;0.352273x0.05)
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                              Axes(0.125,0.59;0.352273x0.05)
# Changes in inventories                                                                       Axes(0.547727,0.59;0.352273x0.05)
# Construction (ISIC F)                                                                           Axes(0.125,0.53;0.352273x0.05)
# Exports of goods and services                                                                Axes(0.547727,0.53;0.352273x0.05)
# Final consumption expenditure                                                                   Axes(0.125,0.47;0.352273x0.05)
# General government final consumption expenditure                                             Axes(0.547727,0.47;0.352273x0.05)
# Gross capital formation                                                                         Axes(0.125,0.41;0.352273x0.05)
# Gross fixed capital formation (including Acquisitions less disposals of valuables)           Axes(0.547727,0.41;0.352273x0.05)
# Household consumption expenditure (including Non-profit institutions serving households)        Axes(0.125,0.35;0.352273x0.05)
# Imports of goods and services                                                                Axes(0.547727,0.35;0.352273x0.05)
# Manufacturing (ISIC D)                                                                          Axes(0.125,0.29;0.352273x0.05)
# Mining, Manufacturing, Utilities (ISIC C-E)                                                  Axes(0.547727,0.29;0.352273x0.05)
# Other Activities (ISIC J-P)                                                                     Axes(0.125,0.23;0.352273x0.05)
# Total Value Added                                                                            Axes(0.547727,0.23;0.352273x0.05)
# Transport, storage and communication (ISIC I)                                                   Axes(0.125,0.17;0.352273x0.05)
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   Axes(0.547727,0.17;0.352273x0.05)
# Gross National Income(GNI) in USD                                                               Axes(0.125,0.11;0.352273x0.05)
# dtype: object

# %% [markdown]
# ## Calculating outliers for each feature

# %%
for col in column:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1

        # Define lower and upper bounds
        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        # Identify outliers
        outliers_lower = df[col] < lower_bound
        outliers_upper = df[col] > upper_bound

        # Transform outliers by capping them at the bounds
        df.loc[outliers_lower, col] = lower_bound
        df.loc[outliers_upper, col] = upper_bound

        print(f"Column: {col}")
        print(f"Lower Bound: {lower_bound}, Upper Bound: {upper_bound}")
        print(f"Number of lower outliers: {outliers_lower.sum()}")
        print(f"Number of upper outliers: {outliers_upper.sum()}\n")
# Out:
# Column:  Year
# Lower Bound: 1946.5, Upper Bound: 2046.5
# Number of lower outliers: 0
# Number of upper outliers: 0
#
# Column:  AMA exchange rate
# Lower Bound: -0.19322997246203222, Upper Bound: -0.09772837153458937
# Number of lower outliers: 0
# Number of upper outliers: 1868
#
# Column:  IMF based exchange rate
# Lower Bound: -0.21608447228052363, Upper Bound: -0.11374213864238115
# Number of lower outliers: 0
# Number of upper outliers: 1883
#
# Column:  Population
# Lower Bound: -0.49368808861903635, Upper Bound: 0.15748486385632005
# Number of lower outliers: 0
# Number of upper outliers: 1315
#
# Column:  Per capita GNI
# Lower Bound: -1.3006030033752811, Upper Bound: 0.8070483743344344
# Number of lower outliers: 0
# Number of upper outliers: 1289
#
# Column:  Agriculture, hunting, forestry, fishing (ISIC A-B)
# Lower Bound: -0.3250198682128714, Upper Bound: 0.06122746739354307
# Number of lower outliers: 0
# Number of upper outliers: 1371
#
# Column:  Changes in inventories
# Lower Bound: -0.4956725452906604, Upper Bound: 0.3079773395678031
# Number of lower outliers: 172
# Number of upper outliers: 710
#
# Column:  Construction (ISIC F)
# Lower Bound: -0.2793193935473533, Upper Bound: -0.062324184732174326
# Number of lower outliers: 0
# Number of upper outliers: 1715
#
# Column:  Exports of goods and services
# Lower Bound: -0.39585118489160936, Upper Bound: -0.050024154638007634
# Number of lower outliers: 0
# Number of upper outliers: 1702
#
# Column:  Final consumption expenditure
# Lower Bound: -0.24966554818261338, Upper Bound: -0.05745639072747505
# Number of lower outliers: 0
# Number of upper outliers: 1619
#
# Column:  General government final consumption expenditure
# Lower Bound: -0.2606085269790895, Upper Bound: -0.0815342134280786
# Number of lower outliers: 0
# Number of upper outliers: 1698
#
# Column:  Gross capital formation
# Lower Bound: -0.2377323188100116, Upper Bound: -0.05916499885034848
# Number of lower outliers: 1
# Number of upper outliers: 1657
#
# Column:  Gross fixed capital formation (including Acquisitions less disposals of valuables)
# Lower Bound: -0.2333697225424134, Upper Bound: -0.06257917212539467
# Number of lower outliers: 0
# Number of upper outliers: 1681
#
# Column:  Household consumption expenditure (including Non-profit institutions serving households)
# Lower Bound: -0.2440208025192509, Upper Bound: -0.05290213912959846
# Number of lower outliers: 0
# Number of upper outliers: 1586
#
# Column:  Imports of goods and services
# Lower Bound: -0.38339973256791976, Upper Bound: -0.03417638455010802
# Number of lower outliers: 0
# Number of upper outliers: 1666
#
# Column:  Manufacturing (ISIC D)
# Lower Bound: -0.2409886769407893, Upper Bound: -0.07191777159010371
# Number of lower outliers: 0
# Number of upper outliers: 1744
#
# Column:  Mining, Manufacturing, Utilities (ISIC C-E)
# Lower Bound: -0.27925199769361614, Upper Bound: -0.04870991067252502
# Number of lower outliers: 0
# Number of upper outliers: 1712
#
# Column:  Other Activities (ISIC J-P)
# Lower Bound: -0.19632792449737335, Upper Bound: -0.08343151247961746
# Number of lower outliers: 0
# Number of upper outliers: 1765
#
# Column:  Total Value Added
# Lower Bound: -0.2480581883183896, Upper Bound: -0.05736997729923936
# Number of lower outliers: 0
# Number of upper outliers: 1638
#
# Column:  Transport, storage and communication (ISIC I)
# Lower Bound: -0.230969941380734, Upper Bound: -0.06412955520452458
# Number of lower outliers: 0
# Number of upper outliers: 1655
#
# Column:  Wholesale, retail trade, restaurants and hotels (ISIC G-H)
# Lower Bound: -0.2470611859455089, Upper Bound: -0.06348113914644878
# Number of lower outliers: 0
# Number of upper outliers: 1659
#
# Column:  Gross National Income(GNI) in USD
# Lower Bound: -0.2539343615157411, Upper Bound: -0.05997531359659482
# Number of lower outliers: 0
# Number of upper outliers: 1654
# C:\Users\katip\AppData\Local\Temp\ipykernel_23516\2101343669.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1946.5' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[outliers_lower, col] = lower_bound

# %% [markdown]
# All these features have outliers in their dataset, but the amount of outliers is quite significant, since it captures a lot of nuanced data about the economics of countries, since we're looking at real world data here, the existence of a large number of outliers implies a pattern within the system that the models we run can immediately identify and fit towards. Thus we opt not to remove the outliers in the model, but we transforming them.

# %%
numerical_columns = df.select_dtypes(include=[np.number]).columns
df[numerical_columns].plot(kind='box', subplots=True, layout=(13, 2), figsize=(10, 50), patch_artist=True)
# Out:
# CountryID                                                                                       Axes(0.125,0.83;0.352273x0.05)
# Country                                                                                      Axes(0.547727,0.83;0.352273x0.05)
# Year                                                                                            Axes(0.125,0.77;0.352273x0.05)
# AMA exchange rate                                                                            Axes(0.547727,0.77;0.352273x0.05)
# IMF based exchange rate                                                                         Axes(0.125,0.71;0.352273x0.05)
# Population                                                                                   Axes(0.547727,0.71;0.352273x0.05)
# Currency                                                                                        Axes(0.125,0.65;0.352273x0.05)
# Per capita GNI                                                                               Axes(0.547727,0.65;0.352273x0.05)
# Agriculture, hunting, forestry, fishing (ISIC A-B)                                              Axes(0.125,0.59;0.352273x0.05)
# Changes in inventories                                                                       Axes(0.547727,0.59;0.352273x0.05)
# Construction (ISIC F)                                                                           Axes(0.125,0.53;0.352273x0.05)
# Exports of goods and services                                                                Axes(0.547727,0.53;0.352273x0.05)
# Final consumption expenditure                                                                   Axes(0.125,0.47;0.352273x0.05)
# General government final consumption expenditure                                             Axes(0.547727,0.47;0.352273x0.05)
# Gross capital formation                                                                         Axes(0.125,0.41;0.352273x0.05)
# Gross fixed capital formation (including Acquisitions less disposals of valuables)           Axes(0.547727,0.41;0.352273x0.05)
# Household consumption expenditure (including Non-profit institutions serving households)        Axes(0.125,0.35;0.352273x0.05)
# Imports of goods and services                                                                Axes(0.547727,0.35;0.352273x0.05)
# Manufacturing (ISIC D)                                                                          Axes(0.125,0.29;0.352273x0.05)
# Mining, Manufacturing, Utilities (ISIC C-E)                                                  Axes(0.547727,0.29;0.352273x0.05)
# Other Activities (ISIC J-P)                                                                     Axes(0.125,0.23;0.352273x0.05)
# Total Value Added                                                                            Axes(0.547727,0.23;0.352273x0.05)
# Transport, storage and communication (ISIC I)                                                   Axes(0.125,0.17;0.352273x0.05)
# Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                   Axes(0.547727,0.17;0.352273x0.05)
# Gross National Income(GNI) in USD                                                               Axes(0.125,0.11;0.352273x0.05)
# dtype: object

# %% [markdown]
# # Assignment 2

# %%
df.drop(columns=[' Country ',' Currency '], inplace=True, axis=1)
x = df.iloc[:, :-1]
y = df.iloc[:, -1]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10254 entries, 0 to 10511
# Data columns (total 24 columns):
#  #   Column                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                      --------------  -----
#  0    CountryID                                                                                  10254 non-null  int64
#  1    Year                                                                                       10254 non-null  float64
#  2    AMA exchange rate                                                                          10254 non-null  float64
#  3    IMF based exchange rate                                                                    10254 non-null  float64
#  4    Population                                                                                 10254 non-null  float64
#  5    Per capita GNI                                                                             10254 non-null  float64
#  6    Agriculture, hunting, forestry, fishing (ISIC A-B)                                         10254 non-null  float64
#  7    Changes in inventories                                                                     10254 non-null  float64
#  8    Construction (ISIC F)                                                                      10254 non-null  float64
#  9    Exports of goods and services                                                              10254 non-null  float64
#  10   Final consumption expenditure                                                              10254 non-null  float64
#  11   General government final consumption expenditure                                           10254 non-null  float64
#  12   Gross capital formation                                                                    10254 non-null  float64
#  13   Gross fixed capital formation (including Acquisitions less disposals of valuables)         10254 non-null  float64
#  14   Household consumption expenditure (including Non-profit institutions serving households)   10254 non-null  float64
#  15   Imports of goods and services                                                              10254 non-null  float64
#  16   Manufacturing (ISIC D)                                                                     10254 non-null  float64
#  17   Mining, Manufacturing, Utilities (ISIC C-E)                                                10254 non-null  float64
#  18   Other Activities (ISIC J-P)                                                                10254 non-null  float64
#  19   Total Value Added                                                                          10254 non-null  float64
#  20   Transport, storage and communication (ISIC I)                                              10254 non-null  float64
#  21   Wholesale, retail trade, restaurants and hotels (ISIC G-H)                                 10254 non-null  float64
#  22   Gross National Income(GNI) in USD                                                          10254 non-null  float64
#  23  Outcome                                                                                     10254 non-null  category
# dtypes: category(1), float64(22), int64(1)
# memory usage: 1.9 MB

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Logistic Regression On Original Data

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=200)

log_reg.fit(X_train, y_train)
log_reg.fit(X_train, y_train)

y_pred = log_reg.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\katip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy: 0.8483666504144319
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.98      0.91      0.94       704
#          Low       0.79      0.86      0.83       644
#       Medium       0.78      0.78      0.78       703
#
#     accuracy                           0.85      2051
#    macro avg       0.85      0.85      0.85      2051
# weighted avg       0.85      0.85      0.85      2051
# C:\Users\katip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.9819600195026816
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      0.99      0.99       704
#          Low       0.97      0.99      0.98       644
#       Medium       0.98      0.96      0.97       703
#
#     accuracy                           0.98      2051
#    macro avg       0.98      0.98      0.98      2051
# weighted avg       0.98      0.98      0.98      2051

# %% [markdown]
# ## Random Forests Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.9897610921501706
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      1.00      1.00       704
#          Low       0.98      1.00      0.99       644
#       Medium       0.99      0.98      0.98       703
#
#     accuracy                           0.99      2051
#    macro avg       0.99      0.99      0.99      2051
# weighted avg       0.99      0.99      0.99      2051

# %% [markdown]
# ## KNN Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)  
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print("Classification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.6352998537298878
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.67      0.69      0.68       704
#          Low       0.61      0.70      0.65       644
#       Medium       0.63      0.52      0.57       703
#
#     accuracy                           0.64      2051
#    macro avg       0.63      0.64      0.63      2051
# weighted avg       0.64      0.64      0.63      2051

# %% [markdown]
# # Feature Selection using Filter Methods

# %%
x = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
import seaborn as sns

corr_matrix = x.corr()
plt.figure(figsize=(16,14))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm')
plt.show()

threshold = 0.9
upper_triangle = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(bool))
to_drop = [column for column in upper_triangle.columns if any(upper_triangle[column] > threshold)]
x1 = x.drop(columns=to_drop)

print("Number of Remaining features:", x1.columns.size)
print("Remaining features:", x1.columns)
# Out:
# Number of Remaining features: 8
# Remaining features: Index([' CountryID ', ' Year ', ' AMA exchange rate ', ' Population ',
#        ' Per capita GNI ',
#        ' Agriculture, hunting, forestry, fishing (ISIC A-B) ',
#        ' Changes in inventories ', ' Construction (ISIC F) '],
#       dtype='object')

# %% [markdown]
# Here we have reduced it down to 10 features, from 26

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

X_train, X_test, y_train, y_test = train_test_split(x1, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

log_reg = LogisticRegression(max_iter=200)
log_reg.fit(X_train, y_train)
log_reg.fit(X_train, y_train)

y_pred = log_reg.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# C:\Users\katip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Logistic Regression Accuracy: 0.749878108239883
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.87      0.82      0.84       704
#          Low       0.72      0.87      0.78       644
#       Medium       0.66      0.58      0.62       703
#
#     accuracy                           0.75      2051
#    macro avg       0.75      0.75      0.75      2051
# weighted avg       0.75      0.75      0.75      2051
# C:\Users\katip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %% [markdown]
# ## Decision Tree Classifer

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.9410043881033642
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.96      0.97      0.96       704
#          Low       0.94      0.95      0.95       644
#       Medium       0.92      0.91      0.91       703
#
#     accuracy                           0.94      2051
#    macro avg       0.94      0.94      0.94      2051
# weighted avg       0.94      0.94      0.94      2051

# %% [markdown]
# ## Random Forests Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.9731838127742565
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.98      0.99      0.98       704
#          Low       0.98      0.97      0.97       644
#       Medium       0.96      0.96      0.96       703
#
#     accuracy                           0.97      2051
#    macro avg       0.97      0.97      0.97      2051
# weighted avg       0.97      0.97      0.97      2051

# %%
from sklearn.svm import SVC

svm = SVC(random_state=42)
svm.fit(X_train, y_train)

y_pred_svm = svm.predict(X_test)

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Classification Report:\n", classification_report(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.34032179424670894
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.49      0.08      0.14       704
#          Low       0.33      0.95      0.49       644
#       Medium       0.38      0.04      0.07       703
#
#     accuracy                           0.34      2051
#    macro avg       0.40      0.36      0.23      2051
# weighted avg       0.40      0.34      0.23      2051

# %% [markdown]
# ## KNN Classifer

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)  
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print("Classification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.6313993174061433
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.66      0.68      0.67       704
#          Low       0.61      0.70      0.65       644
#       Medium       0.63      0.51      0.56       703
#
#     accuracy                           0.63      2051
#    macro avg       0.63      0.63      0.63      2051
# weighted avg       0.63      0.63      0.63      2051

# %% [markdown]
# From this the best performing models are random forests and decision trees, which intuitively makes sense as random forests builds on top of the structure of decision trees. KNNs perform well, since the number of features we're working with pertains to country data, countries that are of a category tend to exist near each other in the 'Economy Indicators' dimensional space. Meanwhile SVMs and logistic regression models perform poorly, this might just be due to the large amount of outliers that are a part of the data.

# %% [markdown]
# # Feature Selection using Wrapper Methods
# ## Logistic Regression

# %%
from sklearn.feature_selection import RFE

model = LogisticRegression(max_iter=200)

rfe = RFE(estimator=model, n_features_to_select=5)
x2 = rfe.fit_transform(x, y)

print("Selected features using RFE:\n", x.columns[rfe.get_support()])
# Out:
# C:\Users\katip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\katip\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Selected features using RFE:
#  Index([' Agriculture, hunting, forestry, fishing (ISIC A-B) ',
#        ' Construction (ISIC F) ', ' Exports of goods and services ',
#        ' Imports of goods and services ',
#        ' Mining, Manufacturing, Utilities (ISIC C-E) '],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(x2, y, test_size=0.2, random_state=42)

log_reg = LogisticRegression(max_iter=200)
log_reg.fit(X_train, y_train)

y_pred = log_reg.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.8600682593856656
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      0.92      0.95       704
#          Low       0.74      0.99      0.85       644
#       Medium       0.89      0.68      0.77       703
#
#     accuracy                           0.86      2051
#    macro avg       0.87      0.86      0.86      2051
# weighted avg       0.88      0.86      0.86      2051

# %% [markdown]
# ## Recursive Feature Elimination Using Decision Trees

# %%
model = DecisionTreeClassifier(random_state=42)

rfe = RFE(estimator=model, n_features_to_select=5)
x2 = rfe.fit_transform(x, y)

print("Selected features using RFE:\n", x.columns[rfe.get_support()])
# Out:
# Selected features using RFE:
#  Index([' Changes in inventories ', ' Exports of goods and services ',
#        ' Manufacturing (ISIC D) ', ' Total Value Added ',
#        ' Gross National Income(GNI) in USD '],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(x2, y, test_size=0.2, random_state=42)

dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.9834227206240859
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      0.99      0.99       704
#          Low       0.97      0.99      0.98       644
#       Medium       0.99      0.96      0.98       703
#
#     accuracy                           0.98      2051
#    macro avg       0.98      0.98      0.98      2051
# weighted avg       0.98      0.98      0.98      2051

# %% [markdown]
# ## Random Forests

# %%
model = RandomForestClassifier()

rfe = RFE(estimator=model, n_features_to_select=5)
x2 = rfe.fit_transform(x, y)

print("Selected features using RFE:\n", x.columns[rfe.get_support()])
# Out:
# Selected features using RFE:
#  Index([' Final consumption expenditure ',
#        ' Gross fixed capital formation (including Acquisitions less disposals of valuables) ',
#        ' Household consumption expenditure (including Non-profit institutions serving households) ',
#        ' Total Value Added ', ' Gross National Income(GNI) in USD '],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(x2, y, test_size=0.2, random_state=42)

rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.9878108239882983
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      1.00      1.00       704
#          Low       0.98      0.99      0.99       644
#       Medium       0.99      0.97      0.98       703
#
#     accuracy                           0.99      2051
#    macro avg       0.99      0.99      0.99      2051
# weighted avg       0.99      0.99      0.99      2051

# %% [markdown]
# ## SVMs

# %%
svm_model = SVC(kernel='linear')
rfe_svm = RFE(estimator=svm_model, n_features_to_select=5)
x2 = rfe_svm.fit_transform(x, y)

print("Selected features using RFE with SVM:\n", x.columns[rfe_svm.get_support()])
# Out:
# Selected features using RFE with SVM:
#  Index([' Agriculture, hunting, forestry, fishing (ISIC A-B) ',
#        ' Construction (ISIC F) ', ' Exports of goods and services ',
#        ' Imports of goods and services ',
#        ' Mining, Manufacturing, Utilities (ISIC C-E) '],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(x2, y, test_size=0.2, random_state=42)

svm_model.fit(X_train, y_train)

y_pred = svm_model.predict(X_test)

print("SVM Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report for SVM:\n", classification_report(y_test, y_pred))
# Out:
# SVM Accuracy: 0.855680156021453
# Classification Report for SVM:
#                precision    recall  f1-score   support
#
#         High       0.99      0.93      0.96       704
#          Low       0.73      1.00      0.84       644
#       Medium       0.90      0.65      0.75       703
#
#     accuracy                           0.86      2051
#    macro avg       0.87      0.86      0.85      2051
# weighted avg       0.88      0.86      0.85      2051

# %% [markdown]
# ## KNN Classifier

# %%
knn_model = KNeighborsClassifier()

rfe_knn = RFE(estimator=RandomForestClassifier(), n_features_to_select=5)  # RFE requires an estimator that has a 'feature_importances_' or 'coef_' attribute
x2_knn = rfe_knn.fit_transform(x, y)

print("Selected features using RFE with KNN:\n", x.columns[rfe_knn.get_support()])
# Out:
# Selected features using RFE with KNN:
#  Index([' Final consumption expenditure ',
#        ' Gross fixed capital formation (including Acquisitions less disposals of valuables) ',
#        ' Household consumption expenditure (including Non-profit institutions serving households) ',
#        ' Total Value Added ', ' Gross National Income(GNI) in USD '],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(x2_knn, y, test_size=0.2, random_state=42)

# Training KNN model
knn_model.fit(X_train, y_train)

# Making predictions
y_pred = knn_model.predict(X_test)

# Evaluating the model
print("KNN Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report for KNN:\n", classification_report(y_test, y_pred))
# Out:
# KNN Accuracy: 0.9839102876645539
# Classification Report for KNN:
#                precision    recall  f1-score   support
#
#         High       0.99      0.99      0.99       704
#          Low       0.98      0.98      0.98       644
#       Medium       0.98      0.97      0.98       703
#
#     accuracy                           0.98      2051
#    macro avg       0.98      0.98      0.98      2051
# weighted avg       0.98      0.98      0.98      2051

# %% [markdown]
# # Feature Reduction

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(x)

# 1. Apply PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# 2. Apply t-SNE
tsne = TSNE(n_components=2, random_state=42)
X_tsne = tsne.fit_transform(X_scaled)

# Visualize the reduced data
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# PCA visualization
ax1.scatter(X_pca[:, 0], X_pca[:, 1], c='blue', label='PCA')
ax1.set_title('PCA: 2 Components')
ax1.set_xlabel('Principal Component 1')
ax1.set_ylabel('Principal Component 2')
ax1.legend()

# t-SNE visualization
ax2.scatter(X_tsne[:, 0], X_tsne[:, 1], c='red', label='t-SNE')
ax2.set_title('t-SNE: 2 Components')
ax2.set_xlabel('t-SNE Component 1')
ax2.set_ylabel('t-SNE Component 2')
ax2.legend()

plt.show()

# %% [markdown]
#  ## PCA

# %%
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

# %%
log_reg = LogisticRegression(max_iter=200)
log_reg.fit(X_train, y_train)
log_reg.fit(X_train, y_train)

y_pred = log_reg.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.9234519746465139
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      0.98      0.99       704
#          Low       0.88      0.91      0.90       644
#       Medium       0.90      0.88      0.89       703
#
#     accuracy                           0.92      2051
#    macro avg       0.92      0.92      0.92      2051
# weighted avg       0.92      0.92      0.92      2051

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.9137006338371526
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.98      0.98      0.98       704
#          Low       0.88      0.89      0.88       644
#       Medium       0.88      0.87      0.87       703
#
#     accuracy                           0.91      2051
#    macro avg       0.91      0.91      0.91      2051
# weighted avg       0.91      0.91      0.91      2051

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.923939541686982
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      0.98      0.99       704
#          Low       0.88      0.91      0.89       644
#       Medium       0.90      0.88      0.89       703
#
#     accuracy                           0.92      2051
#    macro avg       0.92      0.92      0.92      2051
# weighted avg       0.92      0.92      0.92      2051

# %%
svm = SVC(random_state=42)
svm.fit(X_train, y_train)

y_pred_svm = svm.predict(X_test)

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Classification Report:\n", classification_report(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.9219892735251097
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.99      0.98      0.99       704
#          Low       0.87      0.92      0.89       644
#       Medium       0.90      0.87      0.88       703
#
#     accuracy                           0.92      2051
#    macro avg       0.92      0.92      0.92      2051
# weighted avg       0.92      0.92      0.92      2051

# %%
knn = KNeighborsClassifier(n_neighbors=5)  
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print("Classification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.9258898098488543
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.98      0.98      0.98       704
#          Low       0.90      0.90      0.90       644
#       Medium       0.89      0.89      0.89       703
#
#     accuracy                           0.93      2051
#    macro avg       0.93      0.93      0.93      2051
# weighted avg       0.93      0.93      0.93      2051

# %% [markdown]
# ## t-SNE

# %%
X_train, X_test, y_train, y_test = train_test_split(X_tsne, y, test_size=0.2, random_state=42)

# %%
log_reg = LogisticRegression(max_iter=200)
log_reg.fit(X_train, y_train)
log_reg.fit(X_train, y_train)

y_pred = log_reg.predict(X_test)

print("Logistic Regression Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Logistic Regression Accuracy: 0.6918576304241834
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.85      0.88      0.86       704
#          Low       0.64      0.63      0.63       644
#       Medium       0.57      0.56      0.57       703
#
#     accuracy                           0.69      2051
#    macro avg       0.69      0.69      0.69      2051
# weighted avg       0.69      0.69      0.69      2051

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print("Decision Tree Accuracy:", accuracy_score(y_test, y_pred_dt))
print("Classification Report:\n", classification_report(y_test, y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.9527059970745978
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.98      0.98      0.98       704
#          Low       0.95      0.94      0.95       644
#       Medium       0.93      0.93      0.93       703
#
#     accuracy                           0.95      2051
#    macro avg       0.95      0.95      0.95      2051
# weighted avg       0.95      0.95      0.95      2051

# %%
rf = RandomForestClassifier(random_state=42)
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Classification Report:\n", classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Accuracy: 0.961482203803023
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.98      0.99      0.99       704
#          Low       0.95      0.95      0.95       644
#       Medium       0.94      0.94      0.94       703
#
#     accuracy                           0.96      2051
#    macro avg       0.96      0.96      0.96      2051
# weighted avg       0.96      0.96      0.96      2051

# %%
svm = SVC(random_state=42)
svm.fit(X_train, y_train)

y_pred_svm = svm.predict(X_test)

print("SVM Accuracy:", accuracy_score(y_test, y_pred_svm))
print("Classification Report:\n", classification_report(y_test, y_pred_svm))
# Out:
# SVM Accuracy: 0.7898586055582643
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.95      0.92      0.94       704
#          Low       0.68      0.90      0.77       644
#       Medium       0.77      0.56      0.65       703
#
#     accuracy                           0.79      2051
#    macro avg       0.80      0.79      0.78      2051
# weighted avg       0.80      0.79      0.78      2051

# %%
knn = KNeighborsClassifier(n_neighbors=5)  
knn.fit(X_train, y_train)

y_pred_knn = knn.predict(X_test)

print("KNN Accuracy:", accuracy_score(y_test, y_pred_knn))
print("Classification Report:\n", classification_report(y_test, y_pred_knn))
# Out:
# KNN Accuracy: 0.9551438322769381
# Classification Report:
#                precision    recall  f1-score   support
#
#         High       0.97      0.99      0.98       704
#          Low       0.96      0.95      0.95       644
#       Medium       0.94      0.93      0.93       703
#
#     accuracy                           0.96      2051
#    macro avg       0.96      0.95      0.96      2051
# weighted avg       0.96      0.96      0.96      2051

# %% [markdown]
# # Final Analysis
# We see that for:
# 1. Logistic Regression - The wrapper methods work best
# 2. Decision Trees - Similar results are obtained upon feature elimination and the original data.
# 3. Random Forests - Wrapper methods perform marginally better.
# 4. KNN Classifier - Surprisingly, KNNs perform extremely better upon RFE.
#
# From the results obtained, the best performing models are random forests and decision trees, which intuitively makes sense as random forests builds on top of the structure of decision trees. KNNs perform well, since the number of features we're working with pertains to country data, countries that are of a category tend to exist near each other in the 'Economy Indicators' dimensional space. Meanwhile SVMs and logistic regression models perform poorly, this might just be due to the large amount of outliers that are a part of the data.
#
# # Feature Reduction Analysis
# Logistic Regresion - PCA works better compared to t-SNE
# Decision Tree Classifier - t-SNE works better compared to PCA
# Random Forest Classifier - t-SNE works better compared to PCA
# SVM - PCA works significantly better compared to PCA
# KNN - t-SNE works better
